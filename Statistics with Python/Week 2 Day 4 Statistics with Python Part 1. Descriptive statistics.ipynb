# %%
import numpy as np
import pandas as pd

s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from statsmodels.stats.proportion import proportions_ztest

# %%
sns.set()

# %%
# KDE: 
np.random.seed(seed = 1234)
normal =np.random.normal(20, 2, 100000)
sns.distplot(normal, fit=stats.norm, kde=True)

# %%
sns.distplot(normal, fit=stats.norm, kde=False)

# %%
normal.round(3)
# Out:
# array([20.943, 17.618, 22.865, ..., 20.059, 17.559, 20.768])

# %%
normal2 =np.random.normal(30, 2.5, 100000)
sns.distplot(normal, fit=stats.norm, kde=False)

# %%
normal2.round(2)
# Out:
# array([29.06, 29.9 , 30.01, ..., 29.31, 26.45, 33.86])

# %%
normal2.mean()
# Out:
# 29.99576161780797

# %%
normal2.min()
# Out:
# 20.030046160936784

# %%
mu = 115
sig = 20
x = 135

# cumulative distribution density function

prop = stats.norm.cdf(x, mu, sig)

print("%.2f" % ((1-prop)*100))
# Out:
# 15.87

# %%
mu = 12
sigma = 3
x = 12
y = 15
z = 9

propX = stats.norm.cdf(x, mu, sigma)
propY = stats.norm.cdf(y, mu, sigma)
propZ = stats.norm.cdf(z, mu, sigma)

print("%.2f" % (((propX - propZ)*100)))
print("%.2f" % ((propY - propZ)*100))
print("%.2f" % ((1-propZ)*100))
# Out:
# 34.13
# 68.27
# 84.13

# %%
np.random.seed(seed=1234)
norm_normal = np.random.normal(0,1,100000)
sns.distplot(norm_normal)

# %%
norm_normal.round(3)
# Out:
# array([ 0.471, -1.191,  1.433, ...,  0.029, -1.221,  0.384])

# %%
norm_normal = np.random.normal(0,1,10000)
sns.distplot(norm_normal)

# %%
norm_normal = np.random.normal(0,1,1000)
sns.distplot(norm_normal)

# %%
norm_normal = np.random.normal(0,1,100)
sns.distplot(norm_normal)

# %%
norm_normal = np.random.normal(0,1,10)
sns.distplot(norm_normal)

# %%
norm_normal = np.random.normal(0,1,5)
sns.distplot(norm_normal)

# %%
np.random.seed(seed=1234)
t_df29 = np.random.standard_t(df=29, size=1000)
sns.distplot(t_df29, fit = stats.norm, kde = False)

# %%
np.random.seed(seed=1234)
t_df29 = np.random.standard_t(df=29, size=1000)
sns.distplot(t_df29, fit = stats.norm, kde = True)

# %%
np.random.seed(seed=1234)
t_df10 = np.random.standard_t(df=10, size=1000)
sns.distplot(t_df10, fit = stats.norm, kde = False)

# %%
np.random.seed(seed=1234)
t_df10 = np.random.standard_t(df=10, size=1000)
sns.distplot(t_df10, fit = stats.norm, kde = True)

# %%
np.random.seed(seed=1234)
t_df1000 = np.random.standard_t(df=1000, size=1000000)
sns.distplot(t_df1000, fit = stats.norm, kde = True)

# %%
np.random.seed(seed=1234)
t_df1000 = np.random.standard_t(df=10, size=10000)
sns.distplot(t_df1000, fit = stats.norm, kde = False)

# %%
np.random.seed(seed=1234)
t_df1000 = np.random.standard_t(df=50, size=10000)
sns.distplot(t_df1000, fit = stats.norm, kde = False)

# %%
t = 1.53
df = 5

propT = stats.t.cdf(t, df)
print("%.3f" % propT)
# Out:
# 0.907

# %%
t = 1.96
df = 5

propT = stats.t.cdf(t, df)
print("%.3f" % propT)

# 정규분포에서 1.96은 0.975가 나왔을 것
# Out:
# 0.946

# %%
t = 1.96
df = 10000

propT = stats.t.cdf(t, df)
print("%.3f" % propT)

# 자유도가 높아져 = 데이터 수가 많아져, T분포 역시 정규분포와 근사한다.
# Out:
# 0.975

# %%
t = 1.96
df = 1000

propT = stats.t.cdf(t, df)
print("%.3f" % propT)
# Out:
# 0.975

# %% [markdown]
# # Chisquare

# %%
np.random.seed(seed=1234)

# %%
np.random.seed(seed=1234)
chisq_df10 = np.random.chisquare(df = 10, size = 1000)
sns.distplot(chisq_df10, kde = True)

# %%
chisq_df10 = np.random.chisquare(df = 10, size = 1000)
sns.distplot(chisq_df10, fit = stats.norm, kde = True)

# %%
chisq_df10 = np.random.chisquare(df = 10, size = 1000)
sns.distplot(chisq_df10, fit = stats.norm, kde = False)

# %%
chisq_df10 = np.random.chisquare(df = 10, size = 1000)
sns.distplot(chisq_df10, kde = False)

# %%
np.random.seed(seed=1234)
chisq_df40 = np.random.chisquare(df = 40, size = 1000)
sns.distplot(chisq_df40, kde = True)

# %%
np.random.seed(seed=1234)
chisq_df40 = np.random.chisquare(df = 40, size = 1000)
sns.distplot(chisq_df40, fit = stats.norm, kde = True)

# %%
chisq = 10
df = 1000

prop = stats.chi2.cdf(chisq, df)
print("P(X<=%d): %.5f" %(chisq, prop))
# Out:
# P(X<=10): 0.00000

# %%
chisq = 10
df = 30

proppdf = stats.chi2.pdf(chisq, df)
print("P(X=%d): %.5f" %(chisq, proppdf))
# Out:
# P(X=10): 0.00024

# %%
chisq = 3
df = 8

prop = stats.chi2.cdf(chisq, df)
print("P(X<=%d): %.5f" %(chisq, prop))
# Out:
# P(X<=3): 0.06564

# %%
np.random.seed(seed=1234)
F_df10_10 = np.random.f(dfnum=10, dfden=10, size=1000)
sns.distplot(F_df10_10, fit = stats.norm ,kde=True)

# %%
np.random.seed(seed=1234)
F_df5_10 = np.random.f(dfnum=5, dfden=10, size=1000)
sns.distplot(F_df5_10, fit = stats.norm ,kde=True)

# %%
np.random.seed(seed=1234)
F_df100_10 = np.random.f(dfnum=100, dfden=10, size=1000)
sns.distplot(F_df100_10, fit = stats.norm ,kde=True)

# %%
np.random.seed(seed=1234)
F_df10_100 = np.random.f(dfnum=10, dfden=100, size=1000)
sns.distplot(F_df10_100, fit = stats.norm ,kde=True)

# %%
np.random.seed(seed=1234)
F_df100_100 = np.random.f(dfnum=100, dfden=100, size=1000)
sns.distplot(F_df100_100, fit = stats.norm ,kde=True)

# %%
f = 2
dfnum = 15
dfden = 15

propF = stats.f.cdf(x=f, dfn = dfnum, dfd = dfden)
print("%.5f" % propF)
# Out:
# 0.90447

# %%
np.random.seed(seed=1234)
F_df10_10S = np.random.f(dfnum=10000, dfden=10000, size=100000)
sns.distplot(F_df10_10S, fit = stats.norm ,kde=True)

# %% [raw]
# # 와이블 분포는 고장난 이력,,,,,, 파라미터 찾기....
# 설비 신뢰성....
# 고장나는 주기..
# 얼마 안 남은 거 같다..
# 회사에서 쓸까요
# 안씀... 근데 왜 함....????????
#
# 그럼 어디 쓰냐....
# 센서온도/진동분석................
# 트렌드 분석...설비개선...
#
# 와이블분포...어렵고..안쓴다...

# %%
x = 1500
alpha = 2.2
beta = 1200

prop = stats.weibull_min.cdf(x, alpha, scale = beta)
print("%.5f" % (1-prop))
# Out:
# 0.19518

# %%
x = 2500
alpha = 5.2
beta = 2200

prop = stats.weibull_min.cdf(x, alpha, scale = beta)
print("%.5f" % (1-prop))
# Out:
# 0.14313

# %%
x = 1200
alpha = 2.5
beta = 1500

prop = stats.weibull_min.cdf(x, alpha, scale = beta)
print("%.5f" % (1-prop))
# Out:
# 0.56415

# %%
n = 3
for i in range (n+1):
    propbi = stats.binom.pmf(k=i, n=n, p=0.4)
    print ("P(X=%d) : %.3f"% (i, propbi))
# Out:
# P(X=0) : 0.216
# P(X=1) : 0.432
# P(X=2) : 0.288
# P(X=3) : 0.064

# %%
n = 5
for i in range (n+1):
    propbi = stats.binom.pmf(k=i, n=n, p=0.3)
    print ("P(X=%d) : %.3f"% (i, propbi))
# Out:
# P(X=0) : 0.168
# P(X=1) : 0.360
# P(X=2) : 0.309
# P(X=3) : 0.132
# P(X=4) : 0.028
# P(X=5) : 0.002

# %%
n = 100
a = []

for i in range (n+1):
    propbi = stats.binom.pmf(k=i, n=n, p=0.5)
#    print ("P(X=%d) : %.3f"% (i, propbi))
    a.append(propbi)

## line graph

plt.plot(a)
plt.show()

# %%
mu = 2
propcall = stats.poisson.pmf(3, mu)

cdf_prop = stats.poisson.cdf(2, mu)
print ("1분당 %d번의 전화가 걸려올 확률: %.4f" % (3, propcall))
print ("1분당 최대 %d번 이하의 전화가 걸려올 확률: %.4f" % (2, cdf_prop))
# Out:
# 1분당 3번의 전화가 걸려올 확률: 0.1804
# 1분당 최대 2번 이하의 전화가 걸려올 확률: 0.6767

# %%
plt.plot([1,2,3,4])
plt.show()

# %%
mu = 2
prop2cus = stats.poisson.pmf(2, mu)
prop1cus = stats.poisson.cdf(1, mu)
prop3cus = stats.poisson.cdf(2, mu)

# %%
print("2 Customers: %.2f" % prop2cus)
print("Below 1 Customer: %.2f" % prop1cus)
print("Over 3 Customers: %.2f" % (1-prop3cus))
# Out:
# 2 Customers: 0.27
# Below 1 Customer: 0.41
# Over 3 Customers: 0.32

# %%
ds_mycars = pd.read_csv("mycars.csv", engine = "python")

# %%
ds_mycars.head(10)
# Out:
#   manufacturer       model  displacement  year  cylinder automatic driving  \
# 0         audi          a4           1.8  1999         4      auto       f
# 1         audi          a4           1.8  1999         4    manual       f
# 2         audi          a4           2.0  2008         4    manual       f
# 3         audi          a4           2.0  2008         4      auto       f
# 4         audi          a4           2.8  1999         6      auto       f
# 5         audi          a4           2.8  1999         6    manual       f
# 6         audi          a4           3.1  2008         6      auto       f
# 7         audi  a4 quattro           1.8  1999         4    manual       4
# 8         audi  a4 quattro           1.8  1999         4      auto       4
# 9         audi  a4 quattro           2.0  2008         4    manual       4
#
#    mpg  highway_mileage fuel    class
# 0   18               29    p  compact
# 1   21               29    p  compact
# ...

# %%
df = ds_mycars[['model','mpg']]

# %%
df.head(5)
# Out:
#   model  mpg
# 0    a4   18
# 1    a4   21
# 2    a4   20
# 3    a4   21
# 4    a4   16

# %%
df.groupby('model').describe()
# Out:
#                          mpg                                                 \
#                        count       mean       std   min    25%   50%    75%
# model
# 4runner 4wd              6.0  15.166667  0.752773  14.0  15.00  15.0  15.75
# a4                       7.0  18.857143  1.864454  16.0  18.00  18.0  20.50
# a4 quattro               8.0  17.125000  1.807722  15.0  15.75  17.0  18.25
# a6 quattro               3.0  16.000000  1.000000  15.0  15.50  16.0  16.50
# altima                   6.0  20.666667  1.966384  19.0  19.00  20.0  22.50
# c1500 suburban 2wd       5.0  12.800000  1.303840  11.0  12.00  13.0  14.00
# camry                    7.0  19.857143  1.463850  18.0  18.50  21.0  21.00
# camry solara             7.0  19.857143  1.772811  18.0  18.00  21.0  21.00
# caravan 2wd             11.0  15.818182  1.834022  11.0  15.50  16.0  17.00
# civic                    9.0  24.444444  1.943651  21.0  24.00  24.0  25.00
# ...

# %%
ds_mycars.head(10)
# Out:
#   manufacturer       model  displacement  year  cylinder automatic driving  \
# 0         audi          a4           1.8  1999         4      auto       f
# 1         audi          a4           1.8  1999         4    manual       f
# 2         audi          a4           2.0  2008         4    manual       f
# 3         audi          a4           2.0  2008         4      auto       f
# 4         audi          a4           2.8  1999         6      auto       f
# 5         audi          a4           2.8  1999         6    manual       f
# 6         audi          a4           3.1  2008         6      auto       f
# 7         audi  a4 quattro           1.8  1999         4    manual       4
# 8         audi  a4 quattro           1.8  1999         4      auto       4
# 9         audi  a4 quattro           2.0  2008         4    manual       4
#
#    mpg  highway_mileage fuel    class
# 0   18               29    p  compact
# 1   21               29    p  compact
# ...

# %%
df_mycars.groupby('manufacturer').describe()
# Out:
#              displacement                                                  \
#                     count      mean           std  min    25%  50%    75%
# manufacturer
# audi                 18.0  2.544444  6.732032e-01  1.8  2.000  2.8  3.025
# chevrolet            19.0  5.063158  1.370406e+00  2.4  4.450  5.3  5.850
# dodge                37.0  4.378378  8.679910e-01  2.4  3.800  4.7  4.700
# ford                 25.0  4.536000  5.407402e-01  3.8  4.000  4.6  4.600
# honda                 9.0  1.711111  1.452966e-01  1.6  1.600  1.6  1.800
# hyundai              14.0  2.428571  3.646464e-01  2.0  2.100  2.4  2.650
# jeep                  8.0  4.575000  1.015241e+00  3.0  3.925  4.7  4.950
# land rover            4.0  4.300000  2.581989e-01  4.0  4.150  4.3  4.450
# lincoln               3.0  5.400000  1.087792e-15  5.4  5.400  5.4  5.400
# mercury               4.0  4.400000  4.898979e-01  4.0  4.000  4.3  4.700
# ...

# %%
df2 = ds_mycars[['manufacturer','mpg']]

# %%
df2.groupby('manufacturer').describe()
# Out:
#                mpg
#              count       mean       std   min   25%   50%    75%   max
# manufacturer
# audi          18.0  17.611111  1.974511  15.0  16.0  17.5  18.75  21.0
# chevrolet     19.0  15.000000  2.924988  11.0  13.5  15.0  16.50  22.0
# dodge         37.0  13.135135  2.485091   9.0  11.0  13.0  15.00  18.0
# ford          25.0  14.000000  1.914854  11.0  13.0  14.0  15.00  18.0
# honda          9.0  24.444444  1.943651  21.0  24.0  24.0  25.00  28.0
# hyundai       14.0  18.642857  1.499084  16.0  18.0  18.5  19.75  21.0
# jeep           8.0  13.500000  2.507133   9.0  12.5  14.0  15.00  17.0
# land rover     4.0  11.500000  0.577350  11.0  11.0  11.5  12.00  12.0
# lincoln        3.0  11.333333  0.577350  11.0  11.0  11.0  11.50  12.0
# mercury        4.0  13.250000  0.500000  13.0  13.0  13.0  13.25  14.0
# nissan        13.0  18.076923  3.426892  12.0  15.0  19.0  19.00  23.0
# pontiac        5.0  17.000000  1.000000  16.0  16.0  17.0  18.00  18.0
# ...

# %%
df3 = ds_mycars[['automatic','mpg']]
df3.groupby('automatic').describe()
# Out:
#              mpg
#            count       mean       std  min   25%   50%   75%   max
# automatic
# auto       157.0  15.968153  3.848777  9.0  13.0  16.0  18.0  29.0
# manual      77.0  18.675325  4.488118  9.0  15.0  18.0  21.0  35.0

# %%
ds_Exh_QC1 = pd.read_csv("EXH_QC1.csv", engine = "python")
ddf = ds_Exh_QC1[['Flaws', 'Period']]

# %%
count = ddf['Flaws'].value_counts().sort_index()

# %%
count
# Out:
# Other       6
# Peel       15
# Scratch    13
# Smudge      6
# Name: Flaws, dtype: int64

# %%
cumcnt = np.cumsum(count)

# %%
cumcnt
# Out:
# Other       6
# Peel       21
# Scratch    34
# Smudge     40
# Name: Flaws, dtype: int64

# %%
percent = count / sum(count) * 100

# %%
percent
# Out:
# Other      15.0
# Peel       37.5
# Scratch    32.5
# Smudge     15.0
# Name: Flaws, dtype: float64

# %%
cumpct = np.cumsum(percent)

# %%
cumpct
# Out:
# Other       15.0
# Peel        52.5
# Scratch     85.0
# Smudge     100.0
# Name: Flaws, dtype: float64

# %%
count_data = pd.DataFrame({'Count':count, 'CumCnt':cumcnt, 'Percent':percent, 'CumPct': cumpct})

# %%
count_data.columns.name='Flaws'

# %%
count_data
# Out:
# Flaws    Count  CumCnt  Percent  CumPct
# Other        6       6     15.0    15.0
# Peel        15      21     37.5    52.5
# Scratch     13      34     32.5    85.0
# Smudge       6      40     15.0   100.0

# %%
count2 = ddf['Period'].value_counts().sort_index()
cumcnt2 = np.cumsum(count2)
percent2 = count2 / sum(count2) * 100
cumpct2 = np.cumsum(percent2)
count_data2 = pd.DataFrame({'Count':count2, 'CumCnt':cumcnt2, 'Percent':percent2, 'CumPct': cumpct2})
count_data2.columns.name='Period'

# %%
count_data2
# Out:
# Period   Count  CumCnt  Percent  CumPct
# Day          7       7     17.5    17.5
# Evening      7      14     17.5    35.0
# Night       19      33     47.5    82.5
# Weekend      7      40     17.5   100.0

# %%
count3 = ds_mycars['mpg'].value_counts().sort_index()
cumcnt3 = np.cumsum(count3)
percent3 = count3 / sum(count3) * 100
cumpct3 = np.cumsum(percent3)
count_data3 = pd.DataFrame({'Count':count3, 'CumCnt':cumcnt3, 'Percent':percent3, 'CumPct': cumpct3})
count_data3.columns.name='mpg'

# %%
count_data3
# Out:
# mpg  Count  CumCnt    Percent      CumPct
# 9        5       5   2.136752    2.136752
# 11      20      25   8.547009   10.683761
# 12       8      33   3.418803   14.102564
# 13      21      54   8.974359   23.076923
# 14      19      73   8.119658   31.196581
# 15      24      97  10.256410   41.452991
# 16      19     116   8.119658   49.572650
# 17      16     132   6.837607   56.410256
# 18      26     158  11.111111   67.521368
# 19      20     178   8.547009   76.068376
# 20      11     189   4.700855   80.769231
# 21      23     212   9.829060   90.598291
# 22       4     216   1.709402   92.307692
# 23       3     219   1.282051   93.589744
# 24       5     224   2.136752   95.726496
# 25       2     226   0.854701   96.581197
# 26       3     229   1.282051   97.863248
# 28       2     231   0.854701   98.717949
# 29       1     232   0.427350   99.145299
# 33       1     233   0.427350   99.572650
# 35       1     234   0.427350  100.000000
